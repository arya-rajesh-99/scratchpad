# %% [markdown]
# <a href="https://colab.research.google.com/github/arya-rajesh-99/scratchpad/blob/main/nb_2026_01_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/arya-rajesh-99/scratchpad
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 27 (delta 2), reused 1 (delta 1), pack-reused 23 (from 1)
# Receiving objects: 100% (27/27), 28.81 KiB | 9.60 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
import urllib.request
import os
import zipfile
import os

def download_data(force=False):
    """Download and extract course data from Zenodo."""

    zip_path = 'data.zip'
    data_dir = './data'

    if not os.path.exists(zip_path) or force:
        print("Downloading course data...")
        urllib.request.urlretrieve(
            'https://zenodo.org/records/18235955/files/data.zip?download=1',
            zip_path
        )
        print("Download complete")

    if not os.path.exists(data_dir) or force:
        print("Extracting data files...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(data_dir)
        print("Data extracted")

    return data_dir


if __name__ == "__main__":
    download_data()
# Out:
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import pandas as pd
df = pd.read_csv("./data/tech_stocks.csv")
df.head()
# Out:
#    Unnamed: 0 symbol        date   open   high    low  close  close_adjusted  \
# 0           0   MSFT  2016-05-16  50.80  51.96  50.75  51.83         49.7013
# 1           1   MSFT  2002-01-16  68.85  69.84  67.85  67.87         22.5902
# 2           2   MSFT  2001-09-18  53.41  55.00  53.17  54.32         18.0802
# 3           3   MSFT  2007-10-26  36.01  36.03  34.56  35.03         27.2232
# 4           4   MSFT  2014-06-27  41.61  42.29  41.51  42.25         38.6773
#
#       volume  split_coefficient
# 0   20032017                1.0
# 1   30977700                1.0
# 2   41591300                1.0
# 3  288121200                1.0
# 4   74640000                1.0

# %%
df.shape
df.dtypes
# Out:
# Unnamed: 0             int64
# symbol                object
# date                  object
# open                 float64
# high                 float64
# low                  float64
# close                float64
# close_adjusted       float64
# volume                 int64
# split_coefficient    float64
# dtype: object

# %%
df["close_adjusted"].plot()
# Out:
# <Axes: >

# %%
df["close"].plot()
# Out:
# <Axes: >
